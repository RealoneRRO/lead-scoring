# %%
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
lead = pd.read_csv('leads.csv')
lead.T
# Out:
#                                                                                0     \
# Prospect ID                                    7927b2df-8bba-4d29-b9a2-b6e0beafe620
# Lead Number                                                                  660737
# Lead Origin                                                                     API
# Lead Source                                                              Olark Chat
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         0
# TotalVisits                                                                     0.0
# Total Time Spent on Website                                                       0
# Page Views Per Visit                                                            0.0
# Last Activity                                               Page Visited on Website
# Country                                                                         NaN
# Specialization                                                               Select
# How did you hear about X Education                                           Select
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                                    Interested in other courses
# Lead Quality                                                       Low in Relevance
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                                 Select
# City                                                                         Select
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                02.Medium
# Asymmetrique Activity Score                                                    15.0
# Asymmetrique Profile Score                                                     15.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                           No
# Last Notable Activity                                                      Modified
#
#                                                                                1     \
# Prospect ID                                    2a272436-5132-4136-86fa-dcc88c88f482
# Lead Number                                                                  660728
# Lead Origin                                                                     API
# Lead Source                                                          Organic Search
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         0
# TotalVisits                                                                     5.0
# Total Time Spent on Website                                                     674
# Page Views Per Visit                                                            2.5
# Last Activity                                                          Email Opened
# Country                                                                       India
# Specialization                                                               Select
# How did you hear about X Education                                           Select
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                                                        Ringing
# Lead Quality                                                                    NaN
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                                 Select
# City                                                                         Select
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                02.Medium
# Asymmetrique Activity Score                                                    15.0
# Asymmetrique Profile Score                                                     15.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                           No
# Last Notable Activity                                                  Email Opened
#
#                                                                                2     \
# Prospect ID                                    8cc8c611-a219-4f35-ad23-fdfd2656bd8a
# Lead Number                                                                  660727
# Lead Origin                                                 Landing Page Submission
# Lead Source                                                          Direct Traffic
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         1
# TotalVisits                                                                     2.0
# Total Time Spent on Website                                                    1532
# Page Views Per Visit                                                            2.0
# Last Activity                                                          Email Opened
# Country                                                                       India
# Specialization                                              Business Administration
# How did you hear about X Education                                           Select
# What is your current occupation                                             Student
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                            Will revert after reading the email
# Lead Quality                                                               Might be
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                         Potential Lead
# City                                                                         Mumbai
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                  01.High
# Asymmetrique Activity Score                                                    14.0
# Asymmetrique Profile Score                                                     20.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                          Yes
# Last Notable Activity                                                  Email Opened
#
#                                                                                3     \
# Prospect ID                                    0cc2df48-7cf4-4e39-9de9-19797f9b38cc
# Lead Number                                                                  660719
# Lead Origin                                                 Landing Page Submission
# Lead Source                                                          Direct Traffic
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         0
# TotalVisits                                                                     1.0
# Total Time Spent on Website                                                     305
# Page Views Per Visit                                                            1.0
# Last Activity                                                           Unreachable
# Country                                                                       India
# Specialization                                                Media and Advertising
# How did you hear about X Education                                    Word Of Mouth
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                                                        Ringing
# Lead Quality                                                               Not Sure
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                                 Select
# City                                                                         Mumbai
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                  01.High
# Asymmetrique Activity Score                                                    13.0
# Asymmetrique Profile Score                                                     17.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                           No
# Last Notable Activity                                                      Modified
#
#                                                                                4     \
# Prospect ID                                    3256f628-e534-4826-9d63-4a8b88782852
# Lead Number                                                                  660681
# Lead Origin                                                 Landing Page Submission
# Lead Source                                                                  Google
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         1
# TotalVisits                                                                     2.0
# Total Time Spent on Website                                                    1428
# Page Views Per Visit                                                            1.0
# Last Activity                                                     Converted to Lead
# Country                                                                       India
# Specialization                                                               Select
# How did you hear about X Education                                            Other
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                            Will revert after reading the email
# Lead Quality                                                               Might be
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                                 Select
# City                                                                         Mumbai
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                  01.High
# Asymmetrique Activity Score                                                    15.0
# Asymmetrique Profile Score                                                     18.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                           No
# Last Notable Activity                                                      Modified
#
#                                                                                5     \
# Prospect ID                                    2058ef08-2858-443e-a01f-a9237db2f5ce
# Lead Number                                                                  660680
# Lead Origin                                                                     API
# Lead Source                                                              Olark Chat
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         0
# TotalVisits                                                                     0.0
# Total Time Spent on Website                                                       0
# Page Views Per Visit                                                            0.0
# Last Activity                                               Olark Chat Conversation
# Country                                                                         NaN
# Specialization                                                                  NaN
# How did you hear about X Education                                              NaN
# What is your current occupation                                                 NaN
# What matters most to you in choosing a course                                   NaN
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                                                            NaN
# Lead Quality                                                                    NaN
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                                    NaN
# City                                                                            NaN
# Asymmetrique Activity Index                                                 01.High
# Asymmetrique Profile Index                                                02.Medium
# Asymmetrique Activity Score                                                    17.0
# Asymmetrique Profile Score                                                     15.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                           No
# Last Notable Activity                                                      Modified
#
#                                                                                6     \
# Prospect ID                                    9fae7df4-169d-489b-afe4-0f3d752542ed
# Lead Number                                                                  660673
# Lead Origin                                                 Landing Page Submission
# Lead Source                                                                  Google
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         1
# TotalVisits                                                                     2.0
# Total Time Spent on Website                                                    1640
# Page Views Per Visit                                                            2.0
# Last Activity                                                          Email Opened
# Country                                                                       India
# Specialization                                              Supply Chain Management
# How did you hear about X Education                                    Online Search
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                            Will revert after reading the email
# Lead Quality                                                       Low in Relevance
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                         Potential Lead
# City                                                                         Mumbai
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                  01.High
# Asymmetrique Activity Score                                                    14.0
# Asymmetrique Profile Score                                                     20.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                           No
# Last Notable Activity                                                      Modified
#
#                                                                                7     \
# Prospect ID                                    20ef72a2-fb3b-45e0-924e-551c5fa59095
# Lead Number                                                                  660664
# Lead Origin                                                                     API
# Lead Source                                                              Olark Chat
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         0
# TotalVisits                                                                     0.0
# Total Time Spent on Website                                                       0
# Page Views Per Visit                                                            0.0
# Last Activity                                               Olark Chat Conversation
# Country                                                                         NaN
# Specialization                                                                  NaN
# How did you hear about X Education                                              NaN
# What is your current occupation                                                 NaN
# What matters most to you in choosing a course                                   NaN
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                                                            NaN
# Lead Quality                                                                    NaN
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                                    NaN
# City                                                                            NaN
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                02.Medium
# Asymmetrique Activity Score                                                    15.0
# Asymmetrique Profile Score                                                     15.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                           No
# Last Notable Activity                                                      Modified
#
#                                                                                8     \
# Prospect ID                                    cfa0128c-a0da-4656-9d47-0aa4e67bf690
# Lead Number                                                                  660624
# Lead Origin                                                 Landing Page Submission
# Lead Source                                                          Direct Traffic
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         0
# TotalVisits                                                                     2.0
# Total Time Spent on Website                                                      71
# Page Views Per Visit                                                            2.0
# Last Activity                                                          Email Opened
# Country                                                                       India
# Specialization                                               IT Projects Management
# How did you hear about X Education                                              NaN
# What is your current occupation                                                 NaN
# What matters most to you in choosing a course                                   NaN
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                                                            NaN
# Lead Quality                                                                    NaN
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                                    NaN
# City                                                              Thane & Outskirts
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                02.Medium
# Asymmetrique Activity Score                                                    14.0
# Asymmetrique Profile Score                                                     14.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                          Yes
# Last Notable Activity                                                  Email Opened
#
#                                                                                9     \
# Prospect ID                                    af465dfc-7204-4130-9e05-33231863c4b5
# Lead Number                                                                  660616
# Lead Origin                                                                     API
# Lead Source                                                                  Google
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         0
# TotalVisits                                                                     4.0
# Total Time Spent on Website                                                      58
# Page Views Per Visit                                                            4.0
# Last Activity                                                          Email Opened
# Country                                                                       India
# Specialization                                                   Finance Management
# How did you hear about X Education                                    Word Of Mouth
# What is your current occupation                                                 NaN
# What matters most to you in choosing a course                                   NaN
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                                                            NaN
# Lead Quality                                                                    NaN
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                                    NaN
# City                                                                         Mumbai
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                02.Medium
# Asymmetrique Activity Score                                                    13.0
# Asymmetrique Profile Score                                                     16.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                           No
# Last Notable Activity                                                  Email Opened
#
#                                                ...  \
# Prospect ID                                    ...
# Lead Number                                    ...
# Lead Origin                                    ...
# Lead Source                                    ...
# Do Not Email                                   ...
# Do Not Call                                    ...
# Converted                                      ...
# TotalVisits                                    ...
# Total Time Spent on Website                    ...
# Page Views Per Visit                           ...
# Last Activity                                  ...
# Country                                        ...
# Specialization                                 ...
# How did you hear about X Education             ...
# What is your current occupation                ...
# What matters most to you in choosing a course  ...
# Search                                         ...
# Magazine                                       ...
# Newspaper Article                              ...
# X Education Forums                             ...
# Newspaper                                      ...
# Digital Advertisement                          ...
# Through Recommendations                        ...
# Receive More Updates About Our Courses         ...
# Tags                                           ...
# Lead Quality                                   ...
# Update me on Supply Chain Content              ...
# Get updates on DM Content                      ...
# Lead Profile                                   ...
# City                                           ...
# Asymmetrique Activity Index                    ...
# Asymmetrique Profile Index                     ...
# Asymmetrique Activity Score                    ...
# Asymmetrique Profile Score                     ...
# I agree to pay the amount through cheque       ...
# A free copy of Mastering The Interview         ...
# Last Notable Activity                          ...
#
#                                                                                9230  \
# Prospect ID                                    d11c15b7-8056-45a6-8954-771c0d0495fe
# Lead Number                                                                  579701
# Lead Origin                                                 Landing Page Submission
# Lead Source                                                                  Google
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         0
# TotalVisits                                                                     2.0
# Total Time Spent on Website                                                     870
# Page Views Per Visit                                                            2.0
# Last Activity                                                          Email Opened
# Country                                                                       India
# Specialization                                            Human Resource Management
# How did you hear about X Education                                    Online Search
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                            Will revert after reading the email
# Lead Quality                                                                    NaN
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                         Potential Lead
# City                                                                         Mumbai
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                  01.High
# Asymmetrique Activity Score                                                    13.0
# Asymmetrique Profile Score                                                     20.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                           No
# Last Notable Activity                                                  Email Opened
#
#                                                                                9231  \
# Prospect ID                                    4aeae36b-2b57-494f-bdab-dd58844286b4
# Lead Number                                                                  579697
# Lead Origin                                                 Landing Page Submission
# Lead Source                                                                  Google
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         1
# TotalVisits                                                                     8.0
# Total Time Spent on Website                                                    1016
# Page Views Per Visit                                                            4.0
# Last Activity                                                          Email Opened
# Country                                                                       India
# Specialization                                    Banking, Investment And Insurance
# How did you hear about X Education                                    Online Search
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                            Will revert after reading the email
# Lead Quality                                                      High in Relevance
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                         Potential Lead
# City                                                                         Mumbai
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                  01.High
# Asymmetrique Activity Score                                                    15.0
# Asymmetrique Profile Score                                                     20.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                           No
# Last Notable Activity                                                  Email Opened
#
#                                                                                9232  \
# Prospect ID                                    2d0109e9-dfb2-4664-83de-c2ea75ec7516
# Lead Number                                                                  579642
# Lead Origin                                                 Landing Page Submission
# Lead Source                                                          Direct Traffic
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         0
# TotalVisits                                                                     2.0
# Total Time Spent on Website                                                    1770
# Page Views Per Visit                                                            2.0
# Last Activity                                                              SMS Sent
# Country                                                                       India
# Specialization                                            Human Resource Management
# How did you hear about X Education                                           Select
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                                                        Ringing
# Lead Quality                                                               Not Sure
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                         Potential Lead
# City                                                                         Mumbai
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                  01.High
# Asymmetrique Activity Score                                                    14.0
# Asymmetrique Profile Score                                                     20.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                          Yes
# Last Notable Activity                                                      SMS Sent
#
#                                                                                9233  \
# Prospect ID                                    3f715465-2546-47cd-afa8-8b8dc63b8b43
# Lead Number                                                                  579622
# Lead Origin                                                                     API
# Lead Source                                                          Direct Traffic
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         1
# TotalVisits                                                                    13.0
# Total Time Spent on Website                                                    1409
# Page Views Per Visit                                                            2.6
# Last Activity                                                              SMS Sent
# Country                                                                       India
# Specialization                                                               Select
# How did you hear about X Education                                           Select
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                            Will revert after reading the email
# Lead Quality                                                                    NaN
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                                 Select
# City                                                                         Select
# Asymmetrique Activity Index                                                     NaN
# Asymmetrique Profile Index                                                      NaN
# ...
# Do Not Call                                                                      No
# Converted                                                                         1
# TotalVisits                                                                     8.0
# Total Time Spent on Website                                                    1845
# Page Views Per Visit                                                           2.67
# Last Activity                                                     Email Marked Spam
# Country                                                                Saudi Arabia
# Specialization                                               IT Projects Management
# How did you hear about X Education                                           Select
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                            Will revert after reading the email
# Lead Quality                                                      High in Relevance
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                         Potential Lead
# City                                                                         Mumbai
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                  01.High
# Asymmetrique Activity Score                                                    15.0
# Asymmetrique Profile Score                                                     17.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                           No
# Last Notable Activity                                             Email Marked Spam
#
#                                                                                9236  \
# Prospect ID                                    82a7005b-7196-4d56-95ce-a79f937a158d
# Lead Number                                                                  579546
# Lead Origin                                                 Landing Page Submission
# Lead Source                                                          Direct Traffic
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         0
# TotalVisits                                                                     2.0
# Total Time Spent on Website                                                     238
# Page Views Per Visit                                                            2.0
# Last Activity                                                              SMS Sent
# Country                                                                       India
# Specialization                                                Media and Advertising
# How did you hear about X Education                                           Select
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                                             wrong number given
# Lead Quality                                                               Might be
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                         Potential Lead
# City                                                                         Mumbai
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                  01.High
# Asymmetrique Activity Score                                                    14.0
# Asymmetrique Profile Score                                                     19.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                          Yes
# Last Notable Activity                                                      SMS Sent
#
#                                                                                9237  \
# Prospect ID                                    aac550fe-a586-452d-8d3c-f1b62c94e02c
# Lead Number                                                                  579545
# Lead Origin                                                 Landing Page Submission
# Lead Source                                                          Direct Traffic
# Do Not Email                                                                    Yes
# Do Not Call                                                                      No
# Converted                                                                         0
# TotalVisits                                                                     2.0
# Total Time Spent on Website                                                     199
# Page Views Per Visit                                                            2.0
# Last Activity                                                              SMS Sent
# Country                                                                       India
# Specialization                                              Business Administration
# How did you hear about X Education                                           Select
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                                                 invalid number
# Lead Quality                                                               Not Sure
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                         Potential Lead
# City                                                                         Mumbai
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                  01.High
# Asymmetrique Activity Score                                                    13.0
# Asymmetrique Profile Score                                                     20.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                          Yes
# Last Notable Activity                                                      SMS Sent
#
#                                                                                9238  \
# Prospect ID                                    5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9
# Lead Number                                                                  579538
# Lead Origin                                                 Landing Page Submission
# Lead Source                                                                  Google
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         1
# TotalVisits                                                                     3.0
# Total Time Spent on Website                                                     499
# Page Views Per Visit                                                            3.0
# Last Activity                                                              SMS Sent
# Country                                                                       India
# Specialization                                            Human Resource Management
# How did you hear about X Education                                    Online Search
# What is your current occupation                                                 NaN
# What matters most to you in choosing a course                                   NaN
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                                                            NaN
# Lead Quality                                                                    NaN
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                                    NaN
# City                                                             Other Metro Cities
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                02.Medium
# Asymmetrique Activity Score                                                    15.0
# Asymmetrique Profile Score                                                     16.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                           No
# Last Notable Activity                                                      SMS Sent
#
#                                                                                9239
# Prospect ID                                    571b5c8e-a5b2-4d57-8574-f2ffb06fdeff
# Lead Number                                                                  579533
# Lead Origin                                                 Landing Page Submission
# Lead Source                                                          Direct Traffic
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         1
# TotalVisits                                                                     6.0
# Total Time Spent on Website                                                    1279
# Page Views Per Visit                                                            3.0
# Last Activity                                                              SMS Sent
# Country                                                                  Bangladesh
# Specialization                                              Supply Chain Management
# How did you hear about X Education                                           Select
# What is your current occupation                                          Unemployed
# What matters most to you in choosing a course               Better Career Prospects
# Search                                                                           No
# Magazine                                                                         No
# Newspaper Article                                                                No
# X Education Forums                                                               No
# Newspaper                                                                        No
# Digital Advertisement                                                            No
# Through Recommendations                                                          No
# Receive More Updates About Our Courses                                           No
# Tags                                            Will revert after reading the email
# Lead Quality                                                               Might be
# Update me on Supply Chain Content                                                No
# Get updates on DM Content                                                        No
# Lead Profile                                                         Potential Lead
# City                                                                   Other Cities
# Asymmetrique Activity Index                                               02.Medium
# Asymmetrique Profile Index                                                  01.High
# Asymmetrique Activity Score                                                    15.0
# Asymmetrique Profile Score                                                     18.0
# I agree to pay the amount through cheque                                         No
# A free copy of Mastering The Interview                                          Yes
# Last Notable Activity                                                      Modified
#
# [37 rows x 9240 columns]

# %% [markdown]
# ## Exploratory Data Analysis(EDA)

# %%
lead.dtypes
# Out:
# Prospect ID                                       object
# Lead Number                                        int64
# Lead Origin                                       object
# Lead Source                                       object
# Do Not Email                                      object
# Do Not Call                                       object
# Converted                                          int64
# TotalVisits                                      float64
# Total Time Spent on Website                        int64
# Page Views Per Visit                             float64
# Last Activity                                     object
# Country                                           object
# Specialization                                    object
# How did you hear about X Education                object
# What is your current occupation                   object
# What matters most to you in choosing a course     object
# Search                                            object
# Magazine                                          object
# Newspaper Article                                 object
# X Education Forums                                object
# Newspaper                                         object
# Digital Advertisement                             object
# Through Recommendations                           object
# Receive More Updates About Our Courses            object
# Tags                                              object
# Lead Quality                                      object
# Update me on Supply Chain Content                 object
# Get updates on DM Content                         object
# Lead Profile                                      object
# City                                              object
# Asymmetrique Activity Index                       object
# Asymmetrique Profile Index                        object
# Asymmetrique Activity Score                      float64
# Asymmetrique Profile Score                       float64
# I agree to pay the amount through cheque          object
# A free copy of Mastering The Interview            object
# Last Notable Activity                             object
# dtype: object

# %%
lead.columns = lead.columns.str.lower().str.replace(' ', '_')

categorical_columns = list(lead.dtypes[lead.dtypes == 'object'].index)


for c in categorical_columns:
    lead[c] = lead[c].str.lower().str.replace(' ', '_')
    lead[c] = lead[c].replace(to_replace=np.nan, value='unk')

# %%
lead.describe().round()
# Out:
#        lead_number  converted  totalvisits  total_time_spent_on_website  \
# count       9240.0     9240.0       9103.0                       9240.0
# mean      617188.0        0.0          3.0                        488.0
# std        23406.0        0.0          5.0                        548.0
# min       579533.0        0.0          0.0                          0.0
# 25%       596484.0        0.0          1.0                         12.0
# 50%       615479.0        0.0          3.0                        248.0
# 75%       637387.0        1.0          5.0                        936.0
# max       660737.0        1.0        251.0                       2272.0
#
#        page_views_per_visit  asymmetrique_activity_score  \
# count                9103.0                       5022.0
# mean                    2.0                         14.0
# std                     2.0                          1.0
# min                     0.0                          7.0
# 25%                     1.0                         14.0
# 50%                     2.0                         14.0
# 75%                     3.0                         15.0
# max                    55.0                         18.0
#
#        asymmetrique_profile_score
# count                      5022.0
# mean                         16.0
# std                           2.0
# min                          11.0
# 25%                          15.0
# 50%                          16.0
# 75%                          18.0
# max                          20.0

# %%
#for c in ['asymmetrique_profile_score', 'asymmetrique_activity_score']:
    #lead[c] = lead[c].replace(to_replace="16", value=np.nan)

# %%
lead.isnull().sum()
# Out:
# prospect_id                                         0
# lead_number                                         0
# lead_origin                                         0
# lead_source                                         0
# do_not_email                                        0
# do_not_call                                         0
# converted                                           0
# totalvisits                                       137
# total_time_spent_on_website                         0
# page_views_per_visit                              137
# last_activity                                       0
# country                                             0
# specialization                                      0
# how_did_you_hear_about_x_education                  0
# what_is_your_current_occupation                     0
# what_matters_most_to_you_in_choosing_a_course       0
# search                                              0
# magazine                                            0
# newspaper_article                                   0
# x_education_forums                                  0
# newspaper                                           0
# digital_advertisement                               0
# through_recommendations                             0
# receive_more_updates_about_our_courses              0
# tags                                                0
# lead_quality                                        0
# update_me_on_supply_chain_content                   0
# get_updates_on_dm_content                           0
# lead_profile                                        0
# city                                                0
# asymmetrique_activity_index                         0
# asymmetrique_profile_index                          0
# asymmetrique_activity_score                      4218
# asymmetrique_profile_score                       4218
# i_agree_to_pay_the_amount_through_cheque            0
# a_free_copy_of_mastering_the_interview              0
# last_notable_activity                               0
# dtype: int64

# %%
lead
# Out:
#                                prospect_id  lead_number  \
# 0     7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737
# 1     2a272436-5132-4136-86fa-dcc88c88f482       660728
# 2     8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727
# 3     0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719
# 4     3256f628-e534-4826-9d63-4a8b88782852       660681
# ...                                    ...          ...
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9       579564
# 9236  82a7005b-7196-4d56-95ce-a79f937a158d       579546
# 9237  aac550fe-a586-452d-8d3c-f1b62c94e02c       579545
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9       579538
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff       579533
#
#                   lead_origin     lead_source do_not_email do_not_call  \
# 0                         api      olark_chat           no          no
# 1                         api  organic_search           no          no
# 2     landing_page_submission  direct_traffic           no          no
# 3     landing_page_submission  direct_traffic           no          no
# 4     landing_page_submission          google           no          no
# ...                       ...             ...          ...         ...
# 9235  landing_page_submission  direct_traffic          yes          no
# 9236  landing_page_submission  direct_traffic           no          no
# 9237  landing_page_submission  direct_traffic          yes          no
# 9238  landing_page_submission          google           no          no
# 9239  landing_page_submission  direct_traffic           no          no
#
#       converted  totalvisits  total_time_spent_on_website  \
# 0             0          0.0                            0
# 1             0          5.0                          674
# 2             1          2.0                         1532
# 3             0          1.0                          305
# 4             1          2.0                         1428
# ...         ...          ...                          ...
# 9235          1          8.0                         1845
# 9236          0          2.0                          238
# 9237          0          2.0                          199
# 9238          1          3.0                          499
# 9239          1          6.0                         1279
#
#       page_views_per_visit  ... get_updates_on_dm_content    lead_profile  \
# 0                     0.00  ...                        no          select
# 1                     2.50  ...                        no          select
# 2                     2.00  ...                        no  potential_lead
# 3                     1.00  ...                        no          select
# 4                     1.00  ...                        no          select
# ...                    ...  ...                       ...             ...
# 9235                  2.67  ...                        no  potential_lead
# 9236                  2.00  ...                        no  potential_lead
# 9237                  2.00  ...                        no  potential_lead
# 9238                  3.00  ...                        no             unk
# 9239                  3.00  ...                        no  potential_lead
#
#                     city asymmetrique_activity_index  \
# 0                 select                   02.medium
# 1                 select                   02.medium
# 2                 mumbai                   02.medium
# 3                 mumbai                   02.medium
# 4                 mumbai                   02.medium
# ...                  ...                         ...
# 9235              mumbai                   02.medium
# 9236              mumbai                   02.medium
# 9237              mumbai                   02.medium
# 9238  other_metro_cities                   02.medium
# 9239        other_cities                   02.medium
#
#      asymmetrique_profile_index asymmetrique_activity_score  \
# 0                     02.medium                        15.0
# 1                     02.medium                        15.0
# 2                       01.high                        14.0
# 3                       01.high                        13.0
# 4                       01.high                        15.0
# ...                         ...                         ...
# 9235                    01.high                        15.0
# 9236                    01.high                        14.0
# 9237                    01.high                        13.0
# 9238                  02.medium                        15.0
# 9239                    01.high                        15.0
#
#      asymmetrique_profile_score i_agree_to_pay_the_amount_through_cheque  \
# 0                          15.0                                       no
# 1                          15.0                                       no
# 2                          20.0                                       no
# 3                          17.0                                       no
# 4                          18.0                                       no
# ...                         ...                                      ...
# 9235                       17.0                                       no
# 9236                       19.0                                       no
# 9237                       20.0                                       no
# 9238                       16.0                                       no
# 9239                       18.0                                       no
#
#      a_free_copy_of_mastering_the_interview last_notable_activity
# 0                                        no              modified
# 1                                        no          email_opened
# 2                                       yes          email_opened
# 3                                        no              modified
# 4                                        no              modified
# ...                                     ...                   ...
# 9235                                     no     email_marked_spam
# 9236                                    yes              sms_sent
# 9237                                    yes              sms_sent
# 9238                                     no              sms_sent
# 9239                                    yes              modified
#
# [9240 rows x 37 columns]

# %%
tts = pd.to_numeric(lead.total_time_spent_on_website, errors='coerce')

# %%
lead.total_time_spent_on_website = pd.to_numeric(lead.total_time_spent_on_website, errors='coerce')

# %%
tts.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9235    False
# 9236    False
# 9237    False
# 9238    False
# 9239    False
# Name: total_time_spent_on_website, Length: 9240, dtype: bool

# %% [markdown]
# all false shown their is no single row with nan. we can always check in following cell.

# %%
lead[tts.isnull()][['prospect_id', 'total_time_spent_on_website']]
# Out:
# Empty DataFrame
# Columns: [prospect_id, total_time_spent_on_website]
# Index: []

# %%
lead.converted.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: converted, dtype: int64

# %%
lead.converted = (lead.converted == 1).astype(int)
lead.converted
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 9235    1
# 9236    0
# 9237    0
# 9238    1
# 9239    1
# Name: converted, Length: 9240, dtype: int64

# %%
for c in ['asymmetrique_profile_score', 'asymmetrique_activity_score']:
        lead[c] = lead[c].replace(to_replace=np.nan, value=16)
for c in ['page_views_per_visit', 'totalvisits']:
        lead[c] = lead[c].replace(to_replace=np.nan, value=3)

# %% [markdown]
# ## SETTING UP VALDATION FRAMEWORK

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(lead, test_size=0.2, random_state=1)

# %% [markdown]
# The above code train_test_split split the dataset into two. So, we will need to split it again.

# %%
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (5544, 1848, 1848)

# %%
y_train = df_train.reset_index(drop=True)
y_val = df_val.reset_index(drop=True)
y_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.converted.values
y_val = df_val.converted.values
y_test = df_test.converted.values

# %%
del df_train['converted']
del df_val['converted']
del df_test['converted']

# %%
df_full_train = df_full_train.reset_index(drop=True)

# %%
df_full_train.converted.value_counts(normalize=True)
# Out:
# converted
# 0    0.616883
# 1    0.383117
# Name: proportion, dtype: float64

# %%
global_converted_rate = df_full_train.converted.mean()
round(global_converted_rate, 3)
# Out:
# np.float64(0.383)

# %%
lead.dtypes[lead.dtypes == "object"]
# Out:
# prospect_id                                      object
# lead_origin                                      object
# lead_source                                      object
# do_not_email                                     object
# do_not_call                                      object
# last_activity                                    object
# country                                          object
# specialization                                   object
# how_did_you_hear_about_x_education               object
# what_is_your_current_occupation                  object
# what_matters_most_to_you_in_choosing_a_course    object
# search                                           object
# magazine                                         object
# newspaper_article                                object
# x_education_forums                               object
# newspaper                                        object
# digital_advertisement                            object
# through_recommendations                          object
# receive_more_updates_about_our_courses           object
# tags                                             object
# lead_quality                                     object
# update_me_on_supply_chain_content                object
# get_updates_on_dm_content                        object
# lead_profile                                     object
# city                                             object
# asymmetrique_activity_index                      object
# asymmetrique_profile_index                       object
# i_agree_to_pay_the_amount_through_cheque         object
# a_free_copy_of_mastering_the_interview           object
# last_notable_activity                            object
# dtype: object

# %%
numerical = ['totalvisits', 'total_time_spent_on_website', 'page_views_per_visit', 
             'asymmetrique_activity_score', 'asymmetrique_profile_score']
categorical = [ 'lead_origin', 'lead_source', 'do_not_email','do_not_call',                                      
               'last_activity', 'country', 'specialization', 'how_did_you_hear_about_x_education', 
               'what_is_your_current_occupation',                  
               'what_matters_most_to_you_in_choosing_a_course', 'search', 'magazine', 'newspaper_article', 
               'x_education_forums',                               
               'newspaper', 'digital_advertisement', 'through_recommendations', 'receive_more_updates_about_our_courses', 
               'tags',                                             
               'lead_quality', 'update_me_on_supply_chain_content', 'get_updates_on_dm_content', 'lead_profile', 
               'city', 'asymmetrique_activity_index', 'asymmetrique_profile_index', 
               'i_agree_to_pay_the_amount_through_cheque', 'a_free_copy_of_mastering_the_interview', 
               'last_notable_activity']

# %%
df_full_train[categorical].nunique()
# Out:
# lead_origin                                       5
# lead_source                                      20
# do_not_email                                      2
# do_not_call                                       2
# last_activity                                    17
# country                                          37
# specialization                                   20
# how_did_you_hear_about_x_education               11
# what_is_your_current_occupation                   7
# what_matters_most_to_you_in_choosing_a_course     3
# search                                            2
# magazine                                          1
# newspaper_article                                 2
# x_education_forums                                1
# newspaper                                         2
# digital_advertisement                             2
# through_recommendations                           2
# receive_more_updates_about_our_courses            1
# tags                                             27
# lead_quality                                      6
# update_me_on_supply_chain_content                 1
# get_updates_on_dm_content                         1
# lead_profile                                      7
# city                                              8
# asymmetrique_activity_index                       4
# asymmetrique_profile_index                        4
# i_agree_to_pay_the_amount_through_cheque          1
# a_free_copy_of_mastering_the_interview            2
# last_notable_activity                            16
# dtype: int64

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# looking at the lead rate within the group

# %%
df_full_train
# Out:
#                                prospect_id  lead_number  \
# 0     e00e7924-260f-4ad7-8ad5-a246813affc0       609012
# 1     db7df067-c985-4d24-80af-c72990c68904       634813
# 2     1ab4347a-252d-4d68-b178-6a924cc08c19       627932
# 3     930ff3a2-aa35-4a4d-9f27-04423d302af4       650147
# 4     6b142314-ab04-4b05-9a57-90105cb2b91a       600800
# ...                                    ...          ...
# 7387  4669c092-0616-46e5-a4c6-c57059da0ad6       631869
# 7388  8dafc7c8-2e0e-4bac-b9f2-3a773b5a531f       589866
# 7389  0a80f999-708f-4abb-8508-591f6ef2829d       650770
# 7390  53690d88-52f0-4ce5-b6b8-a13570a6db35       610095
# 7391  9a6688f4-798f-4efc-96f7-dddd677263d3       657995
#
#                   lead_origin     lead_source do_not_email do_not_call  \
# 0     landing_page_submission          google           no          no
# 1               lead_add_form       reference           no          no
# 2     landing_page_submission  direct_traffic           no          no
# 3                         api  referral_sites           no          no
# 4     landing_page_submission  direct_traffic           no          no
# ...                       ...             ...          ...         ...
# 7387  landing_page_submission  organic_search           no          no
# 7388  landing_page_submission          google           no          no
# 7389                      api          google           no          no
# 7390                      api          google           no          no
# 7391  landing_page_submission  organic_search           no          no
#
#       converted  totalvisits  total_time_spent_on_website  \
# 0             0          4.0                          239
# 1             1          0.0                            0
# 2             0          2.0                          271
# 3             0          8.0                           51
# 4             0          1.0                           95
# ...         ...          ...                          ...
# 7387          0          4.0                          502
# 7388          0          3.0                          260
# 7389          0          2.0                          271
# 7390          0          2.0                          444
# 7391          0         12.0                           28
#
#       page_views_per_visit  ... get_updates_on_dm_content    lead_profile  \
# 0                      4.0  ...                        no          select
# 1                      0.0  ...                        no  potential_lead
# 2                      2.0  ...                        no             unk
# 3                      4.0  ...                        no          select
# 4                      1.0  ...                        no             unk
# ...                    ...  ...                       ...             ...
# 7387                   4.0  ...                        no          select
# 7388                   3.0  ...                        no          select
# 7389                   1.0  ...                        no     other_leads
# 7390                   2.0  ...                        no     other_leads
# 7391                   6.0  ...                        no          select
#
#                              city asymmetrique_activity_index  \
# 0                          mumbai                         unk
# 1               thane_&_outskirts                   02.medium
# 2     other_cities_of_maharashtra                         unk
# 3                          select                   02.medium
# 4                          mumbai                         unk
# ...                           ...                         ...
# 7387                       mumbai                         unk
# 7388            thane_&_outskirts                      03.low
# 7389                       select                   02.medium
# 7390                       select                         unk
# 7391                 other_cities                   02.medium
#
#      asymmetrique_profile_index asymmetrique_activity_score  \
# 0                           unk                        16.0
# 1                       01.high                        15.0
# 2                           unk                        16.0
# 3                     02.medium                        15.0
# 4                           unk                        16.0
# ...                         ...                         ...
# 7387                        unk                        16.0
# 7388                    01.high                         9.0
# 7389                  02.medium                        14.0
# 7390                        unk                        16.0
# 7391                  02.medium                        14.0
#
#      asymmetrique_profile_score i_agree_to_pay_the_amount_through_cheque  \
# 0                          16.0                                       no
# 1                          19.0                                       no
# 2                          16.0                                       no
# 3                          13.0                                       no
# 4                          16.0                                       no
# ...                         ...                                      ...
# 7387                       16.0                                       no
# 7388                       17.0                                       no
# 7389                       14.0                                       no
# 7390                       16.0                                       no
# 7391                       16.0                                       no
#
#      a_free_copy_of_mastering_the_interview last_notable_activity
# 0                                        no          email_opened
# 1                                        no              sms_sent
# 2                                       yes          email_opened
# 3                                        no              modified
# 4                                       yes              modified
# ...                                     ...                   ...
# 7387                                    yes          email_opened
# 7388                                     no              modified
# 7389                                     no          email_opened
# 7390                                     no              modified
# 7391                                    yes          email_opened
#
# [7392 rows x 37 columns]

# %%
high_mean = df_full_train[df_full_train.asymmetrique_profile_index == '01.high'].converted.mean()
print('asymmetrique_profile_index == 01.high:', round(high_mean, 3))

medium_mean = df_full_train[df_full_train.asymmetrique_profile_index == '02.medium'].converted.mean()
print('asymmetrique_profile_index == 02.medium:  ', round(medium_mean, 3))
# Out:
# asymmetrique_profile_index == 01.high: 0.483
# asymmetrique_profile_index == 02.medium:   0.304

# %%
no_email_access_mean = df_full_train[df_full_train.do_not_email == 'yes'].converted.mean()
print('do_not_email == yes:', round(no_email_access_mean, 3))

email_access_mean = df_full_train[df_full_train.do_not_email == 'no'].converted.mean()
print('do_not_email == no:  ', round(email_access_mean, 3))
# Out:
# do_not_email == yes: 0.174
# do_not_email == no:   0.401

# %% [markdown]
# converted rate = global mean - group

# %%
global_converted_rate - no_email_access_mean
# Out:
# np.float64(0.2088360032522469)

# %% [markdown]
# Risk Ratio
#
# (group / global) mean they are literally the same but different method

# %%
 no_email_access_mean / global_converted_rate
# Out:
# np.float64(0.45490263557888094)

# %%
 email_access_mean / global_converted_rate
# Out:
# np.float64(1.0473684079360215)

# %%
df_group = df_full_train.groupby(by='asymmetrique_profile_index').converted.agg(['mean'])
df_group['diff'] = df_group['mean'] - global_converted_rate
df_group['risk'] = df_group['mean'] / global_converted_rate
df_group
# Out:
#                                 mean      diff      risk
# asymmetrique_profile_index
# 01.high                     0.482525  0.099408  1.259473
# 02.medium                   0.304191 -0.078926  0.793990
# 03.low                      0.416667  0.033550  1.087571
# unk                         0.382519 -0.000598  0.998438

# %%
for col in categorical:
    print(col)
    df_group = df_full_train.groupby(by=col).converted.agg(['mean'])
    df_group['diff'] = df_group['mean'] - global_converted_rate
    df_group['risk'] = df_group['mean'] / global_converted_rate
    display(df_group)
    print()
    print()
# Out:
# lead_origin
#                              mean      diff      risk
# lead_origin
# api                      0.308414 -0.074702  0.805014
# landing_page_submission  0.360677 -0.022440  0.941427
# lead_add_form            0.919861  0.536744  2.400992
# lead_import              0.225000 -0.158117  0.587288
# quick_add_form           1.000000  0.616883  2.610169
# lead_source
#                        mean      diff      risk
# lead_source
# bing               0.166667 -0.216450  0.435028
# blog               0.000000 -0.383117  0.000000
# click2call         0.750000  0.366883  1.957627
# direct_traffic     0.317624 -0.065493  0.829052
# facebook           0.225000 -0.158117  0.587288
# google             0.400000  0.016883  1.044068
# live_chat          1.000000  0.616883  2.610169
# nc_edm             1.000000  0.616883  2.610169
# olark_chat         0.251768 -0.131349  0.657157
# organic_search     0.374320 -0.008797  0.977038
# pay_per_click_ads  0.000000 -0.383117  0.000000
# press_release      0.000000 -0.383117  0.000000
# reference          0.910588  0.527471  2.376790
# referral_sites     0.268041 -0.115076  0.699633
# social_media       0.500000  0.116883  1.305085
# unk                0.807692  0.424575  2.108214
# welearn            1.000000  0.616883  2.610169
# welearnblog_home   0.000000 -0.383117  0.000000
# welingak_website   0.982906  0.599789  2.565551
# youtubechannel     0.000000 -0.383117  0.000000
# do_not_email
#                   mean      diff      risk
# do_not_email
# no            0.401265  0.018148  1.047368
# yes           0.174281 -0.208836  0.454903
# do_not_call
#                  mean      diff      risk
# do_not_call
# no           0.383033 -0.000083  0.999782
# yes          1.000000  0.616883  2.610169
# last_activity
#                                   mean      diff      risk
# last_activity
# approached_upfront            1.000000  0.616883  2.610169
# converted_to_lead             0.126437 -0.256680  0.330021
# email_bounced                 0.092308 -0.290809  0.240939
# email_link_clicked            0.239437 -0.143680  0.624970
# email_marked_spam             1.000000  0.616883  2.610169
# email_opened                  0.363137 -0.019980  0.947848
# email_received                1.000000  0.616883  2.610169
# form_submitted_on_website     0.255102 -0.128015  0.665860
# had_a_phone_conversation      0.727273  0.344156  1.898305
# olark_chat_conversation       0.086185 -0.296932  0.224958
# page_visited_on_website       0.231518 -0.151599  0.604300
# resubscribed_to_emails        1.000000  0.616883  2.610169
# sms_sent                      0.627611  0.244494  1.638172
# unk                           0.780488  0.397371  2.037205
# unreachable                   0.313433 -0.069684  0.818113
# unsubscribed                  0.265306 -0.117811  0.692494
# view_in_browser_link_clicked  0.166667 -0.216450  0.435028
# country
#                           mean      diff      risk
# country
# asia/pacific_region   0.500000  0.116883  1.305085
# australia             0.222222 -0.160895  0.580038
# bahrain               0.666667  0.283550  1.740113
# bangladesh            0.500000  0.116883  1.305085
# belgium               0.000000 -0.383117  0.000000
# canada                0.000000 -0.383117  0.000000
# china                 0.000000 -0.383117  0.000000
# denmark               1.000000  0.616883  2.610169
# france                0.600000  0.216883  1.566102
# germany               0.250000 -0.133117  0.652542
# ghana                 0.000000 -0.383117  0.000000
# hong_kong             0.500000  0.116883  1.305085
# india                 0.367986 -0.015131  0.960506
# indonesia             0.000000 -0.383117  0.000000
# italy                 0.000000 -0.383117  0.000000
# kenya                 0.000000 -0.383117  0.000000
# kuwait                0.000000 -0.383117  0.000000
# liberia               0.000000 -0.383117  0.000000
# netherlands           0.000000 -0.383117  0.000000
# nigeria               0.000000 -0.383117  0.000000
# oman                  0.750000  0.366883  1.957627
# philippines           0.000000 -0.383117  0.000000
# qatar                 0.000000 -0.383117  0.000000
# russia                0.000000 -0.383117  0.000000
# saudi_arabia          0.222222 -0.160895  0.580038
# singapore             0.416667  0.033550  1.087571
# south_africa          0.500000  0.116883  1.305085
# sri_lanka             0.000000 -0.383117  0.000000
# sweden                0.000000 -0.383117  0.000000
# switzerland           0.000000 -0.383117  0.000000
# uganda                0.000000 -0.383117  0.000000
# united_arab_emirates  0.341463 -0.041653  0.891277
# united_kingdom        0.384615  0.001499  1.003911
# united_states         0.263158 -0.119959  0.686887
# unk                   0.433283  0.050166  1.130941
# unknown               0.333333 -0.049784  0.870056
# vietnam               0.000000 -0.383117  0.000000
# specialization
#                                        mean      diff      risk
# specialization
# banking,_investment_and_insurance  0.458333  0.075216  1.196328
# business_administration            0.457478  0.074361  1.194095
# e-business                         0.408163  0.025046  1.065375
# e-commerce                         0.356322 -0.026795  0.930060
# finance_management                 0.453865  0.070748  1.184665
# healthcare_management              0.504065  0.120948  1.315695
# hospitality_management             0.363636 -0.019481  0.949153
# human_resource_management          0.455474  0.072358  1.188866
# international_business             0.361702 -0.021415  0.944104
# it_projects_management             0.375427 -0.007690  0.979927
# marketing_management               0.479699  0.096582  1.252096
# media_and_advertising              0.411043  0.027926  1.072892
# operations_management              0.470588  0.087471  1.228315
# retail_management                  0.357143 -0.025974  0.932203
# rural_and_agribusiness             0.400000  0.016883  1.044068
# select                             0.418006  0.034890  1.091068
# services_excellence                0.310345 -0.072772  0.810053
# supply_chain_management            0.423488  0.040371  1.105374
# travel_and_tourism                 0.350000 -0.033117  0.913559
# unk                                0.102993 -0.280124  0.268829
# how_did_you_hear_about_x_education
#                                         mean      diff      risk
# how_did_you_hear_about_x_education
# advertisements                      0.450980  0.067864  1.177135
# email                               0.421053  0.037936  1.099019
# multiple_sources                    0.349593 -0.033523  0.912498
# online_search                       0.425868  0.042751  1.111586
# other                               0.412903  0.029786  1.077747
# select                              0.474021  0.090904  1.237276
# sms                                 0.200000 -0.183117  0.522034
# social_media                        0.428571  0.045455  1.118644
# student_of_someschool               0.475410  0.092293  1.240900
# unk                                 0.132151 -0.250966  0.344937
# word_of_mouth                       0.441281  0.058164  1.151819
# what_is_your_current_occupation
#                                      mean      diff      risk
# what_is_your_current_occupation
# businessman                      0.500000  0.116883  1.305085
# housewife                        1.000000  0.616883  2.610169
# other                            0.615385  0.232268  1.606258
# student                          0.359281 -0.023835  0.937785
# unemployed                       0.429491  0.046375  1.121045
# unk                              0.143326 -0.239791  0.374104
# working_professional             0.916071  0.532955  2.391102
# what_matters_most_to_you_in_choosing_a_course
#                                                    mean      diff      risk
# what_matters_most_to_you_in_choosing_a_course
# better_career_prospects                        0.482146  0.099029  1.258483
# flexibility_&_convenience                      0.500000  0.116883  1.305085
# unk                                            0.142127 -0.240990  0.370976
# search
#             mean      diff      risk
# search
# no      0.383146  0.000029  1.000076
# yes     0.363636 -0.019481  0.949153
# magazine
#               mean  diff  risk
# magazine
# no        0.383117   0.0   1.0
# newspaper_article
#                        mean      diff      risk
# newspaper_article
# no                 0.383033 -0.000083  0.999782
# yes                1.000000  0.616883  2.610169
# x_education_forums
#                         mean  diff  risk
# x_education_forums
# no                  0.383117   0.0   1.0
# newspaper
#                mean      diff      risk
# newspaper
# no         0.383169  0.000052  1.000135
# yes        0.000000 -0.383117  0.000000
# digital_advertisement
#                            mean      diff      risk
# digital_advertisement
# no                     0.383221  0.000104  1.000271
# yes                    0.000000 -0.383117  0.000000
# through_recommendations
#                              mean      diff      risk
# through_recommendations
# no                       0.382918 -0.000199  0.999482
# yes                      0.750000  0.366883  1.957627
# receive_more_updates_about_our_courses
#                                             mean  diff  risk
# receive_more_updates_about_our_courses
# no                                      0.383117   0.0   1.0
# tags
#                                                        mean      diff  \
# tags
# already_a_student                                  0.007752 -0.375365
# busy                                               0.567742  0.184625
# closed_by_horizzon                                 0.996454  0.613337
# diploma_holder_(not_eligible)                      0.020833 -0.362284
# graduation_in_progress                             0.063830 -0.319287
# in_confusion_whether_part_time_or_dlp              0.250000 -0.133117
# in_touch_with_eins                                 0.272727 -0.110390
# interested__in_full_time_mba                       0.010989 -0.372128
# interested_in_next_batch                           1.000000  0.616883
# interested_in_other_courses                        0.023810 -0.359307
# invalid_number                                     0.014493 -0.368624
# lateral_student                                    1.000000  0.616883
# lost_to_eins                                       0.979310  0.596193
# lost_to_others                                     0.000000 -0.383117
# not_doing_further_education                        0.000000 -0.383117
# number_not_provided                                0.000000 -0.383117
# opp_hangup                                         0.068966 -0.314151
# recognition_issue_(dec_approval)                   0.000000 -0.383117
# ringing                                            0.028332 -0.354785
# shall_take_in_the_next_coming_month                0.500000  0.116883
# still_thinking                                     0.000000 -0.383117
# switched_off                                       0.020408 -0.362709
# university_not_recognized                          0.000000 -0.383117
# unk                                                0.251030 -0.132087
# want_to_take_admission_but_has_financial_problems  0.250000 -0.133117
# will_revert_after_reading_the_email                0.967013  0.583896
# wrong_number_given                                 0.000000 -0.383117
#
#                                                        risk
# tags
# already_a_student                                  0.020234
# busy                                               1.481903
# closed_by_horizzon                                 2.600914
# diploma_holder_(not_eligible)                      0.054379
# graduation_in_progress                             0.166607
# in_confusion_whether_part_time_or_dlp              0.652542
# in_touch_with_eins                                 0.711864
# interested__in_full_time_mba                       0.028683
# interested_in_next_batch                           2.610169
# interested_in_other_courses                        0.062147
# invalid_number                                     0.037829
# lateral_student                                    2.610169
# lost_to_eins                                       2.556166
# lost_to_others                                     0.000000
# not_doing_further_education                        0.000000
# number_not_provided                                0.000000
# opp_hangup                                         0.180012
# recognition_issue_(dec_approval)                   0.000000
# ringing                                            0.073950
# shall_take_in_the_next_coming_month                1.305085
# still_thinking                                     0.000000
# switched_off                                       0.053269
# university_not_recognized                          0.000000
# unk                                                0.655232
# want_to_take_admission_but_has_financial_problems  0.652542
# will_revert_after_reading_the_email                2.524067
# wrong_number_given                                 0.000000
# lead_quality
#                        mean      diff      risk
# lead_quality
# high_in_relevance  0.948718  0.565601  2.476315
# low_in_relevance   0.803063  0.419947  2.096132
# might_be           0.753392  0.370275  1.966480
# not_sure           0.242597 -0.140520  0.633219
# unk                0.214605 -0.168512  0.560155
# worst              0.020408 -0.362709  0.053269
# update_me_on_supply_chain_content
#                                        mean  diff  risk
# update_me_on_supply_chain_content
# no                                 0.383117   0.0   1.0
# get_updates_on_dm_content
#                                mean  diff  risk
# get_updates_on_dm_content
# no                         0.383117   0.0   1.0
# lead_profile
#                                  mean      diff      risk
# lead_profile
# dual_specialization_student  1.000000  0.616883  2.610169
# lateral_student              0.952381  0.569264  2.485876
# other_leads                  0.351621 -0.031496  0.917790
# potential_lead               0.781591  0.398474  2.040086
# select                       0.404403  0.021286  1.055560
# student_of_someschool        0.024752 -0.358364  0.064608
# unk                          0.142127 -0.240990  0.370976
# city
#                                  mean      diff      risk
# city
# mumbai                       0.401318  0.018201  1.047509
# other_cities                 0.408015  0.024898  1.064987
# other_cities_of_maharashtra  0.437326  0.054209  1.141495
# other_metro_cities           0.401961  0.018844  1.049186
# select                       0.485479  0.102363  1.267184
# thane_&_outskirts            0.447412  0.064295  1.167822
# tier_ii_cities               0.339286 -0.043831  0.885593
# unk                          0.107239 -0.275878  0.279911
# asymmetrique_activity_index
#                                  mean      diff      risk
# asymmetrique_activity_index
# 01.high                      0.313522 -0.069595  0.818344
# 02.medium                    0.428008  0.044891  1.117173
# 03.low                       0.092715 -0.290402  0.242002
# unk                          0.382519 -0.000598  0.998438
# asymmetrique_profile_index
#                                 mean      diff      risk
# asymmetrique_profile_index
# 01.high                     0.482525  0.099408  1.259473
# 02.medium                   0.304191 -0.078926  0.793990
# 03.low                      0.416667  0.033550  1.087571
# unk                         0.382519 -0.000598  0.998438
# i_agree_to_pay_the_amount_through_cheque
#                                               mean  diff  risk
# i_agree_to_pay_the_amount_through_cheque
# no                                        0.383117   0.0   1.0
# a_free_copy_of_mastering_the_interview
#                                            mean      diff      risk
# a_free_copy_of_mastering_the_interview
# no                                      0.39578  0.012663  1.033053
# yes                                     0.35545 -0.027667  0.927785
# last_notable_activity
#                                   mean      diff      risk
# last_notable_activity
# approached_upfront            1.000000  0.616883  2.610169
# email_bounced                 0.160000 -0.223117  0.417627
# email_link_clicked            0.222222 -0.160895  0.580038
# email_marked_spam             1.000000  0.616883  2.610169
# email_opened                  0.364362 -0.018755  0.951046
# email_received                1.000000  0.616883  2.610169
# form_submitted_on_website     0.000000 -0.383117  0.000000
# had_a_phone_conversation      0.900000  0.516883  2.349153
# modified                      0.230430 -0.152687  0.601461
# olark_chat_conversation       0.156863 -0.226254  0.409438
# page_visited_on_website       0.294355 -0.088762  0.768316
# resubscribed_to_emails        1.000000  0.616883  2.610169
# sms_sent                      0.690286  0.307169  1.801763
# unreachable                   0.636364  0.253247  1.661017
# unsubscribed                  0.300000 -0.083117  0.783051
# view_in_browser_link_clicked  0.000000 -0.383117  0.000000

# %% [markdown]
# # Mutual Information
# it the order of how important feature is to the target variables

# %%
from sklearn.metrics import mutual_info_score

# %%
mutual_info_score(df_full_train.converted, df_full_train.do_not_call)
# Out:
# np.float64(0.00012980574800136916)

# %%
mutual_info_score(df_full_train.converted, df_full_train.asymmetrique_profile_index)
# Out:
# np.float64(0.008982885395027132)

# %%
mutual_info_score(df_full_train.converted, df_full_train.do_not_email)
# Out:
# np.float64(0.008910986005496974)

# %%
def mutual_info_converted_score(series):
    return mutual_info_score(series, df_full_train.converted)

# %%
mi = df_full_train[categorical].apply(mutual_info_converted_score)
mi.sort_values(ascending=True)
# Out:
# x_education_forums                               0.000000
# magazine                                         0.000000
# update_me_on_supply_chain_content                0.000000
# receive_more_updates_about_our_courses           0.000000
# i_agree_to_pay_the_amount_through_cheque         0.000000
# get_updates_on_dm_content                        0.000000
# search                                           0.000001
# newspaper                                        0.000065
# do_not_call                                      0.000130
# newspaper_article                                0.000130
# digital_advertisement                            0.000131
# through_recommendations                          0.000151
# a_free_copy_of_mastering_the_interview           0.000745
# country                                          0.004992
# do_not_email                                     0.008911
# asymmetrique_profile_index                       0.008983
# asymmetrique_activity_index                      0.011616
# city                                             0.036014
# specialization                                   0.037845
# how_did_you_hear_about_x_education               0.047740
# lead_origin                                      0.055599
# what_matters_most_to_you_in_choosing_a_course    0.055691
# lead_source                                      0.062451
# last_notable_activity                            0.072517
# last_activity                                    0.088539
# what_is_your_current_occupation                  0.092381
# lead_profile                                     0.113887
# lead_quality                                     0.186122
# tags                                             0.376991
# dtype: float64

# %% [markdown]
# # feature correlation

# %%
df_full_train.totalvisits.max()
# Out:
# np.float64(251.0)

# %%
df_full_train[numerical].corrwith(df_full_train.converted)
# Out:
# totalvisits                    0.032361
# total_time_spent_on_website    0.363470
# page_views_per_visit           0.004602
# asymmetrique_activity_score    0.094017
# asymmetrique_profile_score     0.164407
# dtype: float64

# %% [markdown]
# very high correlation

# %% [markdown]
# # One-Hot encoding

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dv = DictVectorizer(sparse=False)

train_dict = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
z = np.linspace(-7, 7, 51)

# %%
sigmoid(100000)
# Out:
# np.float64(1.0)

# %%
plt.plot(z, sigmoid(z))

# %% [markdown]
# # Logistic Regression
# * Binary Classification
# * Linear vs Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
model.intercept_[0]
# Out:
# np.float64(-0.7041939693159459)

# %%
model.coef_[0].round(3)
# Out:
# array([-4.340e-01, -2.700e-01, -1.004e+00,  2.190e-01,  8.770e-01,
#        -7.950e-01,  8.780e-01,  4.480e-01, -3.080e-01, -4.900e-02,
#        -7.950e-01, -2.370e-01, -2.330e-01, -4.190e-01, -3.310e-01,
#        -3.380e-01,  2.000e-03, -4.080e-01,  7.530e-01,  2.690e-01,
#         6.100e-02, -1.120e-01,  2.400e-02, -2.260e-01, -1.300e-01,
#        -3.100e-01, -6.300e-02,  3.000e-03,  1.600e-02,  6.900e-01,
#        -3.700e-02,  7.000e-01, -4.680e-01, -5.000e-02, -2.960e-01,
#        -2.000e-03, -1.430e-01, -6.000e-03, -1.630e-01, -1.200e-02,
#         3.300e-01, -0.000e+00, -8.230e-01, -2.630e-01, -6.140e-01,
#        -3.140e-01,  4.990e-01, -6.000e-03, -4.000e-03, -1.040e-01,
#         1.800e-02,  2.630e-01,  2.100e-01,  3.040e-01,  3.240e-01,
#        -3.670e-01, -3.370e-01, -7.560e-01,  5.200e-02,  1.120e-01,
#        -8.160e-01, -7.040e-01,  1.690e-01,  7.300e-02, -6.260e-01,
#        -1.120e-01,  1.700e-02, -7.040e-01, -2.600e-02,  2.430e-01,
#         3.450e-01, -2.610e-01,  1.780e-01, -7.040e-01,  1.520e-01,
#        -5.130e-01, -9.090e-01,  7.900e-02,  1.380e-01,  3.240e-01,
#         3.500e-02, -9.500e-02,  3.170e-01, -1.244e+00, -6.920e-01,
#         1.390e-01,  9.150e-01, -4.670e-01,  4.070e-01,  3.820e-01,
#         3.280e-01, -3.000e-02, -9.230e-01,  1.380e-01, -4.670e-01,
#         1.100e-02, -5.700e-02,  4.900e-01, -8.340e-01, -8.090e-01,
#         8.900e-02,  1.390e-01,  1.108e+00,  5.300e-02,  4.000e-01,
#        -1.200e-02, -6.100e-02, -5.900e-01,  2.900e-01, -3.910e-01,
#         4.800e-02,  1.900e-01,  2.420e-01,  3.850e-01,  2.160e-01,
#        -5.110e-01, -2.050e-01, -1.021e+00,  1.043e+00,  8.300e-02,
#        -1.160e-01,  3.100e-02, -1.930e-01, -1.554e+00,  2.000e-03,
#        -1.360e-01, -1.960e-01, -8.400e-02, -7.050e-01, -2.270e-01,
#         5.000e-03,  5.790e-01, -2.130e-01, -2.480e-01, -4.000e-03,
#        -1.230e-01, -4.530e-01, -2.080e-01,  4.500e-02, -1.500e-01,
#         2.900e-02, -6.800e-02,  1.608e+00, -1.580e-01, -7.040e-01,
#        -5.870e-01, -1.170e-01, -7.220e-01,  1.800e-02, -4.600e-02,
#        -7.040e-01, -9.580e-01,  2.540e-01,  1.940e-01,  3.000e-01,
#        -3.700e-02,  4.200e-01,  1.880e-01,  9.400e-02, -3.090e-01,
#        -2.260e-01, -1.200e-02, -2.930e-01,  1.600e-01,  7.800e-02,
#         2.070e-01, -4.420e-01,  9.800e-02,  2.150e-01,  2.340e-01,
#        -1.660e-01, -6.480e-01, -7.590e-01, -2.330e+00,  7.920e-01,
#         4.578e+00, -4.870e-01, -4.000e-02,  4.000e-02,  1.210e-01,
#        -1.433e+00,  4.990e-01, -1.816e+00, -1.665e+00,  9.130e-01,
#         5.761e+00, -1.550e-01, -1.543e+00, -1.162e+00, -7.740e-01,
#        -1.590e-01, -3.012e+00,  1.030e-01, -7.300e-01, -2.527e+00,
#        -3.400e-02,  1.863e+00, -1.840e-01,  3.957e+00, -1.281e+00,
#        -6.880e-01, -1.600e-02,  2.000e-03,  2.600e-02, -7.040e-01,
#        -3.430e-01,  1.490e-01,  3.150e-01, -2.830e-01, -2.320e-01,
#        -5.820e-01,  2.720e-01,  3.170e-01, -1.021e+00, -7.040e-01])

# %%
y_pred = model.predict_proba(X_val)[:, 1]

# %%
lead_decision = (y_pred >= 0.5)
lead_decision
# Out:
# array([False,  True, False, ..., False, False,  True])

# %%
y_val
# Out:
# array([0, 1, 0, ..., 1, 0, 1])

# %%
(lead_decision == y_val).mean()
# Out:
# np.float64(0.9415584415584416)

# %%
lead_pred = pd.DataFrame()
lead_pred['probability'] = y_pred
lead_pred['prediction'] = lead_decision.astype(int)
lead_pred['actual'] = y_val

# %%
lead_pred['correct'] = lead_pred.prediction == lead_pred.actual

# %%
lead_pred.correct.mean()
# Out:
# np.float64(0.9415584415584416)

# %%
lead_decision.astype(int)
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %% [markdown]
# # Model Interpretation

# %%
dict(zip(dv.get_feature_names_out(), model.coef_[0].round(3)))
# Out:
# {'a_free_copy_of_mastering_the_interview=no': np.float64(-0.434),
#  'a_free_copy_of_mastering_the_interview=yes': np.float64(-0.27),
#  'asymmetrique_activity_index=01.high': np.float64(-1.004),
#  'asymmetrique_activity_index=02.medium': np.float64(0.219),
#  'asymmetrique_activity_index=03.low': np.float64(0.877),
#  'asymmetrique_activity_index=unk': np.float64(-0.795),
#  'asymmetrique_activity_score': np.float64(0.878),
#  'asymmetrique_profile_index=01.high': np.float64(0.448),
#  'asymmetrique_profile_index=02.medium': np.float64(-0.308),
#  'asymmetrique_profile_index=03.low': np.float64(-0.049),
#  'asymmetrique_profile_index=unk': np.float64(-0.795),
#  'asymmetrique_profile_score': np.float64(-0.237),
#  'city=mumbai': np.float64(-0.233),
#  'city=other_cities': np.float64(-0.419),
#  'city=other_cities_of_maharashtra': np.float64(-0.331),
#  'city=other_metro_cities': np.float64(-0.338),
#  'city=select': np.float64(0.002),
#  'city=thane_&_outskirts': np.float64(-0.408),
#  'city=tier_ii_cities': np.float64(0.753),
#  'city=unk': np.float64(0.269),
#  'country=asia/pacific_region': np.float64(0.061),
#  'country=australia': np.float64(-0.112),
#  'country=bahrain': np.float64(0.024),
#  'country=bangladesh': np.float64(-0.226),
#  'country=belgium': np.float64(-0.13),
#  'country=canada': np.float64(-0.31),
#  'country=china': np.float64(-0.063),
#  'country=denmark': np.float64(0.003),
#  'country=france': np.float64(0.016),
#  'country=germany': np.float64(0.69),
#  'country=ghana': np.float64(-0.037),
#  'country=hong_kong': np.float64(0.7),
#  'country=india': np.float64(-0.468),
#  'country=indonesia': np.float64(-0.05),
#  'country=italy': np.float64(-0.296),
#  'country=kenya': np.float64(-0.002),
#  'country=kuwait': np.float64(-0.143),
#  'country=liberia': np.float64(-0.006),
#  'country=netherlands': np.float64(-0.163),
#  'country=nigeria': np.float64(-0.012),
#  'country=oman': np.float64(0.33),
#  'country=philippines': np.float64(-0.0),
#  'country=qatar': np.float64(-0.823),
#  'country=russia': np.float64(-0.263),
#  'country=saudi_arabia': np.float64(-0.614),
#  'country=singapore': np.float64(-0.314),
#  'country=south_africa': np.float64(0.499),
#  'country=sri_lanka': np.float64(-0.006),
#  'country=sweden': np.float64(-0.004),
#  'country=uganda': np.float64(-0.104),
#  'country=united_arab_emirates': np.float64(0.018),
#  'country=united_kingdom': np.float64(0.263),
#  'country=united_states': np.float64(0.21),
#  'country=unk': np.float64(0.304),
#  'country=unknown': np.float64(0.324),
#  'digital_advertisement=no': np.float64(-0.367),
#  'digital_advertisement=yes': np.float64(-0.337),
#  'do_not_call=no': np.float64(-0.756),
#  'do_not_call=yes': np.float64(0.052),
#  'do_not_email=no': np.float64(0.112),
#  'do_not_email=yes': np.float64(-0.816),
#  'get_updates_on_dm_content=no': np.float64(-0.704),
#  'how_did_you_hear_about_x_education=advertisements': np.float64(0.169),
#  'how_did_you_hear_about_x_education=email': np.float64(0.073),
#  'how_did_you_hear_about_x_education=multiple_sources': np.float64(-0.626),
#  'how_did_you_hear_about_x_education=online_search': np.float64(-0.112),
#  'how_did_you_hear_about_x_education=other': np.float64(0.017),
#  'how_did_you_hear_about_x_education=select': np.float64(-0.704),
#  'how_did_you_hear_about_x_education=sms': np.float64(-0.026),
#  'how_did_you_hear_about_x_education=social_media': np.float64(0.243),
#  'how_did_you_hear_about_x_education=student_of_someschool': np.float64(0.345),
#  'how_did_you_hear_about_x_education=unk': np.float64(-0.261),
#  'how_did_you_hear_about_x_education=word_of_mouth': np.float64(0.178),
#  'i_agree_to_pay_the_amount_through_cheque=no': np.float64(-0.704),
#  'last_activity=approached_upfront': np.float64(0.152),
#  'last_activity=converted_to_lead': np.float64(-0.513),
#  'last_activity=email_bounced': np.float64(-0.909),
#  'last_activity=email_link_clicked': np.float64(0.079),
#  'last_activity=email_marked_spam': np.float64(0.138),
#  'last_activity=email_opened': np.float64(0.324),
#  'last_activity=email_received': np.float64(0.035),
#  'last_activity=form_submitted_on_website': np.float64(-0.095),
#  'last_activity=had_a_phone_conversation': np.float64(0.317),
#  'last_activity=olark_chat_conversation': np.float64(-1.244),
#  'last_activity=page_visited_on_website': np.float64(-0.692),
#  'last_activity=resubscribed_to_emails': np.float64(0.139),
#  'last_activity=sms_sent': np.float64(0.915),
#  'last_activity=unk': np.float64(-0.467),
#  'last_activity=unreachable': np.float64(0.407),
#  'last_activity=unsubscribed': np.float64(0.382),
#  'last_activity=view_in_browser_link_clicked': np.float64(0.328),
#  'last_notable_activity=email_bounced': np.float64(-0.03),
#  'last_notable_activity=email_link_clicked': np.float64(-0.923),
#  'last_notable_activity=email_marked_spam': np.float64(0.138),
#  'last_notable_activity=email_opened': np.float64(-0.467),
#  'last_notable_activity=email_received': np.float64(0.011),
#  'last_notable_activity=form_submitted_on_website': np.float64(-0.057),
#  'last_notable_activity=had_a_phone_conversation': np.float64(0.49),
#  'last_notable_activity=modified': np.float64(-0.834),
#  'last_notable_activity=olark_chat_conversation': np.float64(-0.809),
#  'last_notable_activity=page_visited_on_website': np.float64(0.089),
#  'last_notable_activity=resubscribed_to_emails': np.float64(0.139),
#  'last_notable_activity=sms_sent': np.float64(1.108),
#  'last_notable_activity=unreachable': np.float64(0.053),
#  'last_notable_activity=unsubscribed': np.float64(0.4),
#  'last_notable_activity=view_in_browser_link_clicked': np.float64(-0.012),
#  'lead_origin=api': np.float64(-0.061),
#  'lead_origin=landing_page_submission': np.float64(-0.59),
#  'lead_origin=lead_add_form': np.float64(0.29),
#  'lead_origin=lead_import': np.float64(-0.391),
#  'lead_origin=quick_add_form': np.float64(0.048),
#  'lead_profile=dual_specialization_student': np.float64(0.19),
#  'lead_profile=lateral_student': np.float64(0.242),
#  'lead_profile=other_leads': np.float64(0.385),
#  'lead_profile=potential_lead': np.float64(0.216),
#  'lead_profile=select': np.float64(-0.511),
#  'lead_profile=student_of_someschool': np.float64(-0.205),
#  'lead_profile=unk': np.float64(-1.021),
#  'lead_quality=high_in_relevance': np.float64(1.043),
#  'lead_quality=low_in_relevance': np.float64(0.083),
#  'lead_quality=might_be': np.float64(-0.116),
#  'lead_quality=not_sure': np.float64(0.031),
#  'lead_quality=unk': np.float64(-0.193),
#  'lead_quality=worst': np.float64(-1.554),
#  'lead_source=bing': np.float64(0.002),
#  'lead_source=blog': np.float64(-0.136),
#  'lead_source=click2call': np.float64(-0.196),
#  'lead_source=direct_traffic': np.float64(-0.084),
#  'lead_source=facebook': np.float64(-0.705),
#  'lead_source=google': np.float64(-0.227),
#  'lead_source=live_chat': np.float64(0.005),
#  'lead_source=nc_edm': np.float64(0.579),
#  'lead_source=olark_chat': np.float64(-0.213),
#  'lead_source=organic_search': np.float64(-0.248),
#  'lead_source=pay_per_click_ads': np.float64(-0.004),
#  'lead_source=press_release': np.float64(-0.123),
#  'lead_source=reference': np.float64(-0.453),
#  'lead_source=referral_sites': np.float64(-0.208),
#  'lead_source=social_media': np.float64(0.045),
#  'lead_source=unk': np.float64(-0.15),
#  'lead_source=welearn': np.float64(0.029),
#  'lead_source=welearnblog_home': np.float64(-0.068),
#  'lead_source=welingak_website': np.float64(1.608),
#  'lead_source=youtubechannel': np.float64(-0.158),
#  'magazine=no': np.float64(-0.704),
#  'newspaper=no': np.float64(-0.587),
#  'newspaper=yes': np.float64(-0.117),
#  'newspaper_article=no': np.float64(-0.722),
#  'newspaper_article=yes': np.float64(0.018),
#  'page_views_per_visit': np.float64(-0.046),
#  'receive_more_updates_about_our_courses=no': np.float64(-0.704),
#  'search=no': np.float64(-0.958),
#  'search=yes': np.float64(0.254),
#  'specialization=banking,_investment_and_insurance': np.float64(0.194),
#  'specialization=business_administration': np.float64(0.3),
#  'specialization=e-business': np.float64(-0.037),
#  'specialization=e-commerce': np.float64(0.42),
#  'specialization=finance_management': np.float64(0.188),
#  'specialization=healthcare_management': np.float64(0.094),
#  'specialization=hospitality_management': np.float64(-0.309),
#  'specialization=human_resource_management': np.float64(-0.226),
#  'specialization=international_business': np.float64(-0.012),
#  'specialization=it_projects_management': np.float64(-0.293),
#  'specialization=marketing_management': np.float64(0.16),
#  'specialization=media_and_advertising': np.float64(0.078),
#  'specialization=operations_management': np.float64(0.207),
#  'specialization=retail_management': np.float64(-0.442),
#  'specialization=rural_and_agribusiness': np.float64(0.098),
#  'specialization=select': np.float64(0.215),
#  'specialization=services_excellence': np.float64(0.234),
#  'specialization=supply_chain_management': np.float64(-0.166),
#  'specialization=travel_and_tourism': np.float64(-0.648),
#  'specialization=unk': np.float64(-0.759),
#  'tags=already_a_student': np.float64(-2.33),
#  'tags=busy': np.float64(0.792),
#  'tags=closed_by_horizzon': np.float64(4.578),
#  'tags=diploma_holder_(not_eligible)': np.float64(-0.487),
#  'tags=graduation_in_progress': np.float64(-0.04),
#  'tags=in_confusion_whether_part_time_or_dlp': np.float64(0.04),
#  'tags=in_touch_with_eins': np.float64(0.121),
#  'tags=interested__in_full_time_mba': np.float64(-1.433),
#  'tags=interested_in_next_batch': np.float64(0.499),
#  'tags=interested_in_other_courses': np.float64(-1.816),
#  'tags=invalid_number': np.float64(-1.665),
#  'tags=lateral_student': np.float64(0.913),
#  'tags=lost_to_eins': np.float64(5.761),
#  'tags=lost_to_others': np.float64(-0.155),
#  'tags=not_doing_further_education': np.float64(-1.543),
#  'tags=number_not_provided': np.float64(-1.162),
#  'tags=opp_hangup': np.float64(-0.774),
#  'tags=recognition_issue_(dec_approval)': np.float64(-0.159),
#  'tags=ringing': np.float64(-3.012),
#  'tags=shall_take_in_the_next_coming_month': np.float64(0.103),
#  'tags=still_thinking': np.float64(-0.73),
#  'tags=switched_off': np.float64(-2.527),
#  'tags=university_not_recognized': np.float64(-0.034),
#  'tags=unk': np.float64(1.863),
#  'tags=want_to_take_admission_but_has_financial_problems': np.float64(-0.184),
#  'tags=will_revert_after_reading_the_email': np.float64(3.957),
#  'tags=wrong_number_given': np.float64(-1.281),
#  'through_recommendations=no': np.float64(-0.688),
#  'through_recommendations=yes': np.float64(-0.016),
#  'total_time_spent_on_website': np.float64(0.002),
#  'totalvisits': np.float64(0.026),
#  'update_me_on_supply_chain_content=no': np.float64(-0.704),
#  'what_is_your_current_occupation=businessman': np.float64(-0.343),
#  'what_is_your_current_occupation=housewife': np.float64(0.149),
#  'what_is_your_current_occupation=other': np.float64(0.315),
#  'what_is_your_current_occupation=student': np.float64(-0.283),
#  'what_is_your_current_occupation=unemployed': np.float64(-0.232),
#  'what_is_your_current_occupation=unk': np.float64(-0.582),
#  'what_is_your_current_occupation=working_professional': np.float64(0.272),
#  'what_matters_most_to_you_in_choosing_a_course=better_career_prospects': np.float64(0.317),
#  'what_matters_most_to_you_in_choosing_a_course=unk': np.float64(-1.021),
#  'x_education_forums=no': np.float64(-0.704)}

# %%
small = ['asymmetrique_activity_score', 'total_time_spent_on_website', 'asymmetrique_profile_score']

# %%
df_train[small].iloc[:10].to_dict(orient='records')
# Out:
# [{'asymmetrique_activity_score': 16.0,
#   'total_time_spent_on_website': 304,
#   'asymmetrique_profile_score': 16.0},
#  {'asymmetrique_activity_score': 16.0,
#   'total_time_spent_on_website': 213,
#   'asymmetrique_profile_score': 16.0},
#  {'asymmetrique_activity_score': 16.0,
#   'total_time_spent_on_website': 811,
#   'asymmetrique_profile_score': 16.0},
#  {'asymmetrique_activity_score': 13.0,
#   'total_time_spent_on_website': 0,
#   'asymmetrique_profile_score': 15.0},
#  {'asymmetrique_activity_score': 11.0,
#   'total_time_spent_on_website': 20,
#   'asymmetrique_profile_score': 15.0},
#  {'asymmetrique_activity_score': 13.0,
#   'total_time_spent_on_website': 50,
#   'asymmetrique_profile_score': 16.0},
#  {'asymmetrique_activity_score': 16.0,
#   'total_time_spent_on_website': 1510,
#   'asymmetrique_profile_score': 16.0},
#  {'asymmetrique_activity_score': 16.0,
#   'total_time_spent_on_website': 0,
#   'asymmetrique_profile_score': 16.0},
#  {'asymmetrique_activity_score': 14.0,
#   'total_time_spent_on_website': 136,
#   'asymmetrique_profile_score': 19.0},
#  {'asymmetrique_activity_score': 13.0,
#   'total_time_spent_on_website': 1475,
#   'asymmetrique_profile_score': 18.0}]

# %%
dicts_train_small = df_train[small].to_dict(orient='records')
dicts_val_small = df_val[small].to_dict(orient='records')

# %%
dv_small = DictVectorizer(sparse=False)
dv_small.fit(dicts_train_small)
# Out:
# DictVectorizer(sparse=False)

# %%
dv_small.get_feature_names_out()
# Out:
# array(['asymmetrique_activity_score', 'asymmetrique_profile_score',
#        'total_time_spent_on_website'], dtype=object)

# %%
X_train_small = dv_small.transform(dicts_train_small)

# %% [markdown]
# Let train the model

# %%
model_small = LogisticRegression()
model_small.fit(X_train_small, y_train)
# Out:
# LogisticRegression()

# %%
dicts_full_train = df_full_train[categorical + numerical].to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=False)
X_full_train = dv.fit_transform(dicts_full_train)

# %%
y_full_train = df_full_train.converted.values

# %%
model_train = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000)
model_train.fit(X_full_train, y_full_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
dicts_test = df_test[categorical + numerical].to_dict(orient='records')

# %%
X_test = dv.transform(dicts_test)

# %%
model.intercept_[0]
# Out:
# np.float64(-0.7041939693159459)

# %%
model.coef_[0].round(3)
# Out:
# array([-4.340e-01, -2.700e-01, -1.004e+00,  2.190e-01,  8.770e-01,
#        -7.950e-01,  8.780e-01,  4.480e-01, -3.080e-01, -4.900e-02,
#        -7.950e-01, -2.370e-01, -2.330e-01, -4.190e-01, -3.310e-01,
#        -3.380e-01,  2.000e-03, -4.080e-01,  7.530e-01,  2.690e-01,
#         6.100e-02, -1.120e-01,  2.400e-02, -2.260e-01, -1.300e-01,
#        -3.100e-01, -6.300e-02,  3.000e-03,  1.600e-02,  6.900e-01,
#        -3.700e-02,  7.000e-01, -4.680e-01, -5.000e-02, -2.960e-01,
#        -2.000e-03, -1.430e-01, -6.000e-03, -1.630e-01, -1.200e-02,
#         3.300e-01, -0.000e+00, -8.230e-01, -2.630e-01, -6.140e-01,
#        -3.140e-01,  4.990e-01, -6.000e-03, -4.000e-03, -1.040e-01,
#         1.800e-02,  2.630e-01,  2.100e-01,  3.040e-01,  3.240e-01,
#        -3.670e-01, -3.370e-01, -7.560e-01,  5.200e-02,  1.120e-01,
#        -8.160e-01, -7.040e-01,  1.690e-01,  7.300e-02, -6.260e-01,
#        -1.120e-01,  1.700e-02, -7.040e-01, -2.600e-02,  2.430e-01,
#         3.450e-01, -2.610e-01,  1.780e-01, -7.040e-01,  1.520e-01,
#        -5.130e-01, -9.090e-01,  7.900e-02,  1.380e-01,  3.240e-01,
#         3.500e-02, -9.500e-02,  3.170e-01, -1.244e+00, -6.920e-01,
#         1.390e-01,  9.150e-01, -4.670e-01,  4.070e-01,  3.820e-01,
#         3.280e-01, -3.000e-02, -9.230e-01,  1.380e-01, -4.670e-01,
#         1.100e-02, -5.700e-02,  4.900e-01, -8.340e-01, -8.090e-01,
#         8.900e-02,  1.390e-01,  1.108e+00,  5.300e-02,  4.000e-01,
#        -1.200e-02, -6.100e-02, -5.900e-01,  2.900e-01, -3.910e-01,
#         4.800e-02,  1.900e-01,  2.420e-01,  3.850e-01,  2.160e-01,
#        -5.110e-01, -2.050e-01, -1.021e+00,  1.043e+00,  8.300e-02,
#        -1.160e-01,  3.100e-02, -1.930e-01, -1.554e+00,  2.000e-03,
#        -1.360e-01, -1.960e-01, -8.400e-02, -7.050e-01, -2.270e-01,
#         5.000e-03,  5.790e-01, -2.130e-01, -2.480e-01, -4.000e-03,
#        -1.230e-01, -4.530e-01, -2.080e-01,  4.500e-02, -1.500e-01,
#         2.900e-02, -6.800e-02,  1.608e+00, -1.580e-01, -7.040e-01,
#        -5.870e-01, -1.170e-01, -7.220e-01,  1.800e-02, -4.600e-02,
#        -7.040e-01, -9.580e-01,  2.540e-01,  1.940e-01,  3.000e-01,
#        -3.700e-02,  4.200e-01,  1.880e-01,  9.400e-02, -3.090e-01,
#        -2.260e-01, -1.200e-02, -2.930e-01,  1.600e-01,  7.800e-02,
#         2.070e-01, -4.420e-01,  9.800e-02,  2.150e-01,  2.340e-01,
#        -1.660e-01, -6.480e-01, -7.590e-01, -2.330e+00,  7.920e-01,
#         4.578e+00, -4.870e-01, -4.000e-02,  4.000e-02,  1.210e-01,
#        -1.433e+00,  4.990e-01, -1.816e+00, -1.665e+00,  9.130e-01,
#         5.761e+00, -1.550e-01, -1.543e+00, -1.162e+00, -7.740e-01,
#        -1.590e-01, -3.012e+00,  1.030e-01, -7.300e-01, -2.527e+00,
#        -3.400e-02,  1.863e+00, -1.840e-01,  3.957e+00, -1.281e+00,
#        -6.880e-01, -1.600e-02,  2.000e-03,  2.600e-02, -7.040e-01,
#        -3.430e-01,  1.490e-01,  3.150e-01, -2.830e-01, -2.320e-01,
#        -5.820e-01,  2.720e-01,  3.170e-01, -1.021e+00, -7.040e-01])

# %% [markdown]
# checking the number of features is in train and test

# %%
print("Number of features in training data:", X_train.shape[1])
# Out:
# Number of features in training data: 215

# %%
print("Number of features in test data:", X_test.shape[1])
# Out:
# Number of features in test data: 219

# %%
X_test_subset = X_test[:, :215]

# %% [markdown]
# now we can predict with subset of test

# %%
y_pred = model.predict_proba(X_test_subset)[:, 1]

# %%
lead_decision = (y_pred >= 0.5)

# %%
(lead_decision == y_test)
# Out:
# array([ True, False, False, ...,  True,  True,  True])

# %%
customer = dicts_test[-1]
customer
# Out:
# {'lead_origin': 'lead_add_form',
#  'lead_source': 'reference',
#  'do_not_email': 'no',
#  'do_not_call': 'no',
#  'last_activity': 'sms_sent',
#  'country': 'unk',
#  'specialization': 'select',
#  'how_did_you_hear_about_x_education': 'select',
#  'what_is_your_current_occupation': 'unemployed',
#  'what_matters_most_to_you_in_choosing_a_course': 'better_career_prospects',
#  'search': 'no',
#  'magazine': 'no',
#  'newspaper_article': 'no',
#  'x_education_forums': 'no',
#  'newspaper': 'no',
#  'digital_advertisement': 'no',
#  'through_recommendations': 'no',
#  'receive_more_updates_about_our_courses': 'no',
#  'tags': 'will_revert_after_reading_the_email',
#  'lead_quality': 'might_be',
#  'update_me_on_supply_chain_content': 'no',
#  'get_updates_on_dm_content': 'no',
#  'lead_profile': 'select',
#  'city': 'select',
#  'asymmetrique_activity_index': 'unk',
#  'asymmetrique_profile_index': 'unk',
#  'i_agree_to_pay_the_amount_through_cheque': 'no',
#  'a_free_copy_of_mastering_the_interview': 'no',
#  'last_notable_activity': 'sms_sent',
#  'totalvisits': 0.0,
#  'total_time_spent_on_website': 0,
#  'page_views_per_visit': 0.0,
#  'asymmetrique_activity_score': 16.0,
#  'asymmetrique_profile_score': 16.0}

# %%
X_small = dv.transform([customer])
X_small_subset = X_small[:, :215]
model.predict_proba(X_small_subset)[0, 1]
# Out:
# np.float64(0.9950535771034629)

# %%
y_test[-1]
# Out:
# np.int64(1)

# %%
lead_decision
# Out:
# array([ True, False, False, ..., False,  True,  True])

# %%
y_val
# Out:
# array([0, 1, 0, ..., 1, 0, 1])
